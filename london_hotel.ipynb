# %%
import pandas as pd
df = pd.read_csv("London_hotel_reviews.csv",  encoding = "ISO-8859-1")
df
# Out:
#                 Property Name  Review Rating  \
# 0      Apex London Wall Hotel              5
# 1      Corinthia Hotel London              5
# 2                   The Savoy              5
# 3                Rhodes Hotel              4
# 4                   The Savoy              5
# ...                       ...            ...
# 27325  Corinthia Hotel London              5
# 27326            A To Z Hotel              3
# 27327           The Rembrandt              4
# 27328          The Dorchester              4
# 27329               The Savoy              5
#
#                                        Review Title  \
# 0                             Ottima qualità prezzo
# 1                By far, my best hotel in the world
# 2      First visit to the American Bar at the Savoy
# 3                                         Nice stay
# 4                                        Perfection
# ...                                             ...
# ...

# %%
df.isna().sum()
# Out:
# Property Name                  0
# Review Rating                  0
# Review Title                   0
# Review Text                    0
# Location Of The Reviewer    3953
# Date Of Review                 1
# dtype: int64

# %%
# rimuovo alcune reviews con caratteri sconosciuti
df = df[df['Review Text'].str.contains("<U") == False] 
print(df.shape)
# Out:
# (26877, 6)

# %%
# tolgo variabili che non interessano
data = df.drop(['Property Name', 'Review Title', 'Date Of Review', 'Location Of The Reviewer' ], axis=1)
data
# Out:
#        Review Rating                                        Review Text
# 0                  5  Siamo stati a Londra per un week end ed abbiam...
# 1                  5  I had a pleasure of staying in this hotel for ...
# 2                  5  A very lovely first visit to this iconic hotel...
# 3                  4  3 of us stayed at the Rhodes Hotel for 4 night...
# 4                  5  Form the moment we arrived until we left we ex...
# ...              ...                                                ...
# 27325              5  I come to London often but since I stayed in t...
# 27326              3  En cuarto que nos tocó no había toallas y habí...
# 27327              4  This is a quality quiet hotel located in an ex...
# 27328              4  Väldigt vackra rum, tyvärr med en mycket höglj...
# 27329              5  I have been staying in London hotels for 10 ye...
#
# [26877 rows x 2 columns]

# %%
data.'Review Rating'.value_counts()
# Out:
#   File "<ipython-input-24-9fcf6ccd5bdf>", line 1
#     data.'Review Rating'.value_counts()
#                        ^
# SyntaxError: invalid syntax
